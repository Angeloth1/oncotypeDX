# %% [markdown]
# # [About the data set](https://www.kaggle.com/datasets/rzemouri/oncotypedx-breast-cancer-dataset?resource=download)
# Ο Oncotype DX (ODX) είναι μια υπογραφή έκφρασης πολλαπλών γονιδίων που έχει σχεδιαστεί για ασθενείς με καρκίνο του μαστού με θετικό υποδοχέα οιστρογόνων (ER) και αρνητικό υποδοχέα του ανθρώπινου επιδερμικού αυξητικού παράγοντα 2 (HER2) για την πρόβλεψη του σκορ υποτροπής (RS) και του οφέλους της χημειοθεραπείας (CT). Σκοπός της μελέτης μας είναι η ανάπτυξη ενός εργαλείου πρόβλεψης για τις τρεις κατηγορίες RS που βασίζεται σε βαθιά πολυεπίπεδα perceptrons (DMLP) και χρησιμοποιεί μόνο τις μορφοανοσοανοσολογικές μεταβλητές. Πραγματοποιήσαμε μια αναδρομική κοόρτη 320 ασθενών που υποβλήθηκαν σε έλεγχο ODX από τρία γαλλικά νοσοκομεία. Καταγράφηκαν τα κλινικοπαθολογικά χαρακτηριστικά. Κατασκευάσαμε ένα μοντέλο ταξινόμησης με επιβλεπόμενη μηχανική μάθηση χρησιμοποιώντας το λογισμικό Matlab με 152 περιπτώσεις για την εκπαίδευση και 168 περιπτώσεις για τη δοκιμή. Χρησιμοποιήθηκαν τρεις ταξινομητές για την εκμάθηση των τριών κατηγοριών κινδύνου της ODX, δηλαδή του χαμηλού, του ενδιάμεσου και του υψηλού κινδύνου. Τα πειραματικά αποτελέσματα παρέχουν την περιοχή κάτω από την καμπύλη (AUC), αντίστοιχα, για τις τρεις κατηγορίες κινδύνου: 0,63 [95% διάστημα εμπιστοσύνης: (0,5446, 0,7154), p < 0,001], 0,59 [95% διάστημα εμπιστοσύνης: (0,5031, 0,6769), p < 0,001], 0,75 [95% διάστημα εμπιστοσύνης: (0,6184, 0,8816), p < 0,001]. Το ποσοστό συμφωνίας μεταξύ του πραγματικού RS και του προβλεπόμενου RS κυμάνθηκε από 53 έως 56% για κάθε κατηγορία μεταξύ DMLP και ODX. Το ποσοστό συμφωνίας της συνδυασμένης ομάδας χαμηλού και ενδιάμεσου κινδύνου ήταν 85%. αναπτύξαμε ένα προγνωστικό μοντέλο μηχανικής μάθησης που θα μπορούσε να βοηθήσει στον καθορισμό της RS του ασθενούς. Επιπλέον, ενσωματώσαμε τα ιστοπαθολογικά δεδομένα και τα αποτελέσματα της DMLP για την επιλογή όγκου για τη δοκιμή ODX. Έτσι, η διαδικασία αυτή επιτρέπει την πιο συναφή χρήση των ιστοπαθολογικών δεδομένων και βελτιστοποιεί και ενισχύει αυτές τις πληροφορίες.
#
# Σχετικές εργασίες και αίτηση αναφοράς:
#
# Πρόβλεψη της βαθμολογίας υποτροπής του Oncotype DX με τη χρήση βαθιών πολυεπίπεδων perceptrons σε καρκίνο του μαστού με θετικούς υποδοχείς οιστρογόνων και αρνητικό HER2
# Μάιος 2020 Καρκίνος του μαστού 27(5)
# DOI: 10.1007/s12282-020-01100-4
#
# Διάγνωση του καρκίνου του μαστού με βάση την από κοινού επιλογή μεταβλητών και το Constructive Deep Neural Network, Μάρτιος 2018, Συνέδριο: 2018 IEEE 4th Middle East Conference on Biomedical Engineering (MECBME), DOI:10.1109/MECBME.2018.8402426
#
# Constructive Deep Neural Network for Breast Cancer Diagnosis, Ιανουάριος 2018, IFAC-PapersOnLine 51(27):98-103, DOI:10.1016/j.ifacol.2018.11.660
#
# ## Target feature
#     Statur ODX
#     -   1 = low value (RS<18)
#     -   2 = mid value (RS18-30)
#     -   3 = high value (RS>30)

# %%
#Libraries
import pandas as pd

# %%
#pandas settings
pd.set_option('display.max_columns',58)
missing_values = ['NA', 'NaN', 'N/A', 'NR', ' ']

# %%
# loading the dataset
#pc version 
# file_path = r'C:\Users\thomo\Desktop\Personal\Uni\Ptixiaki\DataSet\DataSet.xlsx'
#laptop version
file_path = 'DataSet/DataSet.xlsx'
df = pd.read_excel(file_path)
df.replace(missing_values, inplace=True)
target = 'Statut ODX'

# %%
df.head()
# Out:
#          N°Bloc  Type de prélèvement Bloc ODX  Sexe                  DDN  \
# 0  12.11.07.046                    1        E     1 -1105056000000000000
# 1  12.12.18.104                    1      T21     1  -812073600000000000
# 2  13.01.08.103                    1       R1     1  -611539200000000000
# 3  13.01.09.009                    1       I3     1  -114566400000000000
# 4  13.02.05.076                    1       A5     1  -474854400000000000
#
#              Date diag  Age au diag  Ménopause  ATCD K sein  \
# 0  1353024000000000000    77.945205        1.0            2
# 1  1357171200000000000    68.786301        1.0            0
# 2  1358380800000000000    62.465753        1.0            0
# 3  1358467200000000000    46.709589        0.0            0
# 4  1360800000000000000    58.208219        0.0            0
#
#    Consultation oncogénétique  Mutation   Taille tm (mm) Type de gg  \
# 0                         NaN        NaN              14          1
# 1                         NaN        NaN              15          1
# 2                         NaN        NaN               6          1
# 3                         NaN        NaN              80          1
# 4                         1.0        6.0              30          1
#
#    Statut ganglionnaire Nombre de gg+/nb de gg prélevés Type histo  \
# 0                   0.0                             0/1          3
# 1                   0.0                             0/1          1
# 2                   1.0                             0.5          1
# 3                   3.0                             0/1          2
# 4                   0.0                             0/1          1
#
#   Type histo associé  Grade SBR  Grade glandes  Grade nucléaire   \
# 0                  1          3              3                 2
# 1                  5          3              3                 3
# 2                  1          2              3                 2
# 3              2 + 3          2              3                 2
# 4                  1          2              3                 2
#
#    Grade mitoses  Emboles vasculaires  Envahissement périnerveux % Stroma  \
# 0              3                    0                          0       20
# 1              2                    0                          0       30
# 2              1                    0                          0       70
# 3              1                    0                          0       30
# 4              1                    0                          0       20
#
#    % CT  Topographie infiltrat     Stade pTNM  RE (%) RE intensité RE Allred  \
# 0  80.0                    2.0  T1cN0(sn)(i-)     100            3         8
# 1  70.0                    1.0  T1cN0(sn)(i-)      90            3         8
# 2  30.0                    3.0     T1bN1a(sn)      95            3         8
# 3  70.0                    1.0   T3N0(sn)(i+)      90            2         7
# 4  80.0                    2.0   T2N0(sn)(i-)     100            3         8
#
#   RP (%) RP intensité RP Allred HER2 IHC HER2 SISH Ki67 % Lt stroma  \
# 0    100            3         8      NaN       NaN   11           5
# 1     90            3         8      NaN       NaN   24           5
# 2     60            3         7      NaN       NaN   20          30
# 3    100            3         8      NaN       NaN   11           5
# 4      2            2         4      NaN       NaN   10           5
#
#    % CD8 dans tumeur P53  P53 (%) P53 intensité  Score Oncotype  \
# 0                0.0  0*     30.0             1               2
# 1                0.0  0*     20.0             1              15
# 2                5.0  0*     10.0             1              27
# 3                1.0  0*     30.0             1              12
# 4                0.0  0*     10.0             1              16
#
#   Distant recurrence (%) Statut ODX RE Oncotype RE status O RP Oncotype  \
# 0                   0.04          1        11.9    positive         8.8
# 1                    0.1          1        11.1    positive         9.3
# 2                   0.18          2         8.4    positive         6.1
# 3                   0.08          1         7.8    positive         8.5
# 4                    0.1          1        10.3    positive           4
#
#   RP status O HER2 Oncotype HER 2 status O  Chirurgie HT RT Chimithérapie  \
# 0    positive           7.8       négative          1  1  1             0
# 1    positive           9.9       négative          2  1  1             0
# 2    positive             8       négative          2  1  1             0
# 3    positive           9.4       négative          4  1  1             0
# 4    négative           9.2       négative          2  1  1             0
#
#                  DDN.1 EDN Récidive Unnamed: 57
# 0  2016-06-15 00:00:00   V        0         NaN
# 1  2016-10-28 00:00:00   V        0         NaN
# 2  2015-10-16 00:00:00   V        0         NaN
# 3  2018-01-18 00:00:00   V        0         NaN
# 4  2016-10-09 00:00:00   V        0         NaN

# %%
def columnType():
    # Iterate over each column
    for column in df.columns:
        print("----", column, "----")
    
    # Calculate missing values
        missing_count = df[column].isnull().sum()
        print("Missing values:", missing_count)
    
    
    # Check if column is mostly numeric 
        if pd.to_numeric(df[column], errors='coerce').notnull().sum() / len(df[column]) > 0.9: #cheks if for the most part the is numeric
            df[column] = pd.to_numeric(df[column])

        # Calculate statistics
            std_deviation = df[column].std()
            print("Standard deviation:", std_deviation)
        
            mean_value = df[column].mean()
            print("Mean value:", mean_value)
        
            max_value = df[column].max()
            print("Maximum value:", max_value)
        
            min_value = df[column].min()
            print("Minimum value:", min_value)
        
        else:
            print("The feature named", column, "is not numeric")
        
        print("\n")
columnType()
# Out:
# ---- N°Bloc ----
# Missing values: 0
# The feature named N°Bloc is not numeric
#
#
# ---- Type de prélèvement ----
# Missing values: 0
# Standard deviation: 0.3198398158268636
# Mean value: 0.8847352024922118
# Maximum value: 1
# Minimum value: 0
#
#
# ---- Bloc ODX ----
# Missing values: 33
# The feature named Bloc ODX is not numeric
#
#
# ---- Sexe ----
# Missing values: 0
# Standard deviation: 0.05581455721859476
# Mean value: 0.9968847352024922
# Maximum value: 1
# Minimum value: 0
#
#
# ---- DDN ----
# Missing values: 0
# Standard deviation: 3.621924357059397e+17
# Mean value: -3.579145570093458e+17
# Maximum value: 503625600000000000
# Minimum value: -1236729600000000000
#
#
# ---- Date diag ----
# Missing values: 0
# Standard deviation: 4.867620098067768e+16
# Mean value: 1.4319069308411215e+18
# Maximum value: 1547164800000000000
# Minimum value: 1345593600000000000
#
#
# ---- Age au diag ----
# Missing values: 0
# Standard deviation: 11.288386101291726
# Mean value: 56.75486706781036
# Maximum value: 83.84383561643835
# Minimum value: 30.367123287671234
#
#
# ---- Ménopause ----
# Missing values: 1
# Standard deviation: 0.5496864309893351
# Mean value: 0.70625
# Maximum value: 2.0
# Minimum value: 0.0
#
#
# ---- ATCD K sein ----
# Missing values: 0
# Standard deviation: 0.47238788249327457
# Mean value: 0.14330218068535824
# Maximum value: 2
# Minimum value: 0
#
#
# ---- Consultation oncogénétique ----
# Missing values: 270
# The feature named Consultation oncogénétique is not numeric
#
#
# ---- Mutation  ----
# Missing values: 271
# The feature named Mutation  is not numeric
#
#
# ---- Taille tm (mm) ----
# Missing values: 0
# Standard deviation: 11.629812171855916
# Mean value: 19.90031152647975
# Maximum value: 100
# Minimum value: 2
#
#
# ---- Type de gg ----
# Missing values: 0
# Standard deviation: 0.5920192227661283
# Mean value: 1.1838006230529594
# Maximum value: 3.0
# Minimum value: 0.0
#
#
# ---- Statut ganglionnaire ----
# Missing values: 9
# Standard deviation: 0.8873382192509189
# Mean value: 0.7051282051282052
# Maximum value: 3.0
# Minimum value: 0.0
#
#
# ---- Nombre de gg+/nb de gg prélevés ----
# Missing values: 9
# The feature named Nombre de gg+/nb de gg prélevés is not numeric
#
#
# ---- Type histo ----
# Missing values: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1 + 3"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 32
#      29             print("The feature named", column, "is not numeric")
#      31         print("\n")
# ---> 32 columnType()
#
# Cell In[30], line 13, in columnType()
#      11 # Check if column is mostly numeric
#      12     if pd.to_numeric(df[column], errors='coerce').notnull().sum() / len(df[column]) > 0.9: #cheks if for the most part the is numeric
# ---> 13         df[column] = pd.to_numeric(df[column])
#      15     # Calculate statistics
#      16         std_deviation = df[column].std()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/tools/numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1 + 3" at position 148

# %% [markdown]
# ## Βρόμικο dataset
# Υπάρχουν πολλές περιπτώσεις με << λάθος >> συμβολισμούς, για την αντιμετώπιση τους θα προσπαθήσω αρχικά να απομονώσω τις << σημειώσεις >> όπου υπάρχουν μέσα στο data set και προκαλούν error. Στην συνέχεια θα προσπαθήσω να ερμηνεύσω την κάθε μία αντικαθιστώντας την σύμφωνα με τις οδηγίες του dataset. Αν δεν είναι δυνατή μία τέτοια ενέργεια θα αποβάλω αυτό το δήγμα σε ένα unclean dataset που θα χρησιμοποιηθεί είτε για test είτε ως αποθήκη δηγμάτων μέχρι να βρεθεί η ερμηνεία τους.

# %% [markdown]
# ### Type de gg (Cleaning)
# Μετάφραση από gpt
# > τύπος gg: τύπος αδένα
# > - 0 = χωρίς αισθητήρα αδένων ή αφαίρεση
# > - 1 = αισθητήρας αδένων
# > - 2 = άξονας αφαίρεσης
#
# το 1+2 συμβολίζει ότι ανήκει στην κατηγορία 1 και 2 για να μην γίνεται πρόβλημα στην αντιμετώπιση του, θα το μετατρέψω σε μια νέα κατηγορία 3. Κάθε κατηγορία θα παραμείνει ως μια ακέραια τιμή για αρχή για να είναι πιο κοντά στην αρχική απεικόνιση του σετ και στην πορεία αν κριθεί απαραίτητο θα μετατραπούν σε τυχαία σύμβολα.

# %%
df['Type de gg'] = pd.to_numeric(df['Type de gg'], errors='coerce').fillna(3)

print(df['Type de gg'])
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 316    1.0
# 317    1.0
# 318    1.0
# 319    1.0
# 320    1.0
# Name: Type de gg, Length: 321, dtype: float64

# %% [markdown]
# ## Επόμενο βρώμικο feature

# %%
columnType()
# Out:
# ---- N°Bloc ----
# Missing values: 0
# The feature named N°Bloc is not numeric
#
#
# ---- Type de prélèvement ----
# Missing values: 0
# Standard deviation: 0.3198398158268636
# Mean value: 0.8847352024922118
# Maximum value: 1
# Minimum value: 0
#
#
# ---- Bloc ODX ----
# Missing values: 33
# The feature named Bloc ODX is not numeric
#
#
# ---- Sexe ----
# Missing values: 0
# Standard deviation: 0.05581455721859476
# Mean value: 0.9968847352024922
# Maximum value: 1
# Minimum value: 0
#
#
# ---- DDN ----
# Missing values: 0
# Standard deviation: 3.621924357059397e+17
# Mean value: -3.579145570093458e+17
# Maximum value: 503625600000000000
# Minimum value: -1236729600000000000
#
#
# ---- Date diag ----
# Missing values: 0
# Standard deviation: 4.867620098067768e+16
# Mean value: 1.4319069308411215e+18
# Maximum value: 1547164800000000000
# Minimum value: 1345593600000000000
#
#
# ---- Age au diag ----
# Missing values: 0
# Standard deviation: 11.288386101291726
# Mean value: 56.75486706781036
# Maximum value: 83.84383561643835
# Minimum value: 30.367123287671234
#
#
# ---- Ménopause ----
# Missing values: 1
# Standard deviation: 0.5496864309893351
# Mean value: 0.70625
# Maximum value: 2.0
# Minimum value: 0.0
#
#
# ---- ATCD K sein ----
# Missing values: 0
# Standard deviation: 0.47238788249327457
# Mean value: 0.14330218068535824
# Maximum value: 2
# Minimum value: 0
#
#
# ---- Consultation oncogénétique ----
# Missing values: 270
# The feature named Consultation oncogénétique is not numeric
#
#
# ---- Mutation  ----
# Missing values: 271
# The feature named Mutation  is not numeric
#
#
# ---- Taille tm (mm) ----
# Missing values: 0
# Standard deviation: 11.629812171855916
# Mean value: 19.90031152647975
# Maximum value: 100
# Minimum value: 2
#
#
# ---- Type de gg ----
# Missing values: 0
# Standard deviation: 0.5920192227661283
# Mean value: 1.1838006230529594
# Maximum value: 3.0
# Minimum value: 0.0
#
#
# ---- Statut ganglionnaire ----
# Missing values: 9
# Standard deviation: 0.8873382192509189
# Mean value: 0.7051282051282052
# Maximum value: 3.0
# Minimum value: 0.0
#
#
# ---- Nombre de gg+/nb de gg prélevés ----
# Missing values: 9
# The feature named Nombre de gg+/nb de gg prélevés is not numeric
#
#
# ---- Type histo ----
# Missing values: 0
# The feature named Type histo is not numeric
#
#
# ---- Type histo associé ----
# Missing values: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2 + 3"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 columnType()
#
# Cell In[30], line 13, in columnType()
#      11 # Check if column is mostly numeric
#      12     if pd.to_numeric(df[column], errors='coerce').notnull().sum() / len(df[column]) > 0.9: #cheks if for the most part the is numeric
# ---> 13         df[column] = pd.to_numeric(df[column])
#      15     # Calculate statistics
#      16         std_deviation = df[column].std()
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/tools/numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~/.local/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "2 + 3" at position 3

# %% [markdown]
# ### Type histo
# Μετάφραση από gpt
# > Ιστολογικός τύπος:
# > - 1 = διεισδυτικός καρκίνος μη-ειδικού τύπου (= διεισδυτικός καρκίνος ακαναλικού τύπου)
# > - 2 = διεισδυτικός λοβουλώδης καρκίνος
# > - 3 = διεισδυτικός μυξώδης καρκίνος
# > - 4 = διεισδυτικός καρκίνος μη-ειδικού τύπου με ενδοκρινή διαφοροποίηση
# > - 5 = διεισδυτικός καρκίνος με δαχτυλίδια και τρύπημα
# > - 6 = διεισδυτικός μικροπαπιλλώδης καρκίνος
# > - 7 = διεισδυτικός παπιλλώδης καρκίνος

# %%
non_numeric_values = df.loc[~df['Type histo'].apply(pd.to_numeric, errors='coerce').notnull(), 'Type histo']

print(non_numeric_values)
# Out:
# 148    1 + 3
# 165    1 + 3
# 195    1 + 6
# 264    1 + 2
# 269    1 + 2
# 299    1 + 2
# Name: Type histo, dtype: object

# %% [markdown]
# Πρέπει λοιπόν τις τιμές αυτές να της μετατρέψω σε νέες κατηγορίες, αλφαριθμητικές καθώς δεν μπορούν να έχουν κάποια αριθμητική συνοχή πχ αν κάποιος ανοική στην κατηγορία 1 και 3 θα ανοικεί στην κατηγορία 4 καθώς η κατηγορία αυτή αντιπροσοπεύει μια διαφορετική ομάδα. Έχοντας το σε μορφή κειμένου θα μπορώ να έχω περισσότερη συνοχή καθώς η κατηγορίες θα μετονομαστούν σε A B C D E F G και αν κάποιο ανοίχει στην 1 + 3 θα ονομαστή AC κλπ

# %%
mapping = {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G'}
def convert_value(value):
    if isinstance(value, int):
        return mapping.get(value, '')
    elif isinstance(value, str):
        parts = value.split('+')
        parts = [mapping.get(int(part.strip()), '') for part in parts]
        return ''.join(parts)
    return ''
df['Type histo'] = df['Type histo'].apply(convert_value)

# %%
print(df['Type histo'].to_string(index=True))
