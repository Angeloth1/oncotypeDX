# %% [markdown]
# # [About the data set](https://www.kaggle.com/datasets/rzemouri/oncotypedx-breast-cancer-dataset?resource=download)
# Ο Oncotype DX (ODX) είναι μια υπογραφή έκφρασης πολλαπλών γονιδίων που έχει σχεδιαστεί για ασθενείς με καρκίνο του μαστού με θετικό υποδοχέα οιστρογόνων (ER) και αρνητικό υποδοχέα του ανθρώπινου επιδερμικού αυξητικού παράγοντα 2 (HER2) για την πρόβλεψη του σκορ υποτροπής (RS) και του οφέλους της χημειοθεραπείας (CT). Σκοπός της μελέτης μας είναι η ανάπτυξη ενός εργαλείου πρόβλεψης για τις τρεις κατηγορίες RS που βασίζεται σε βαθιά πολυεπίπεδα perceptrons (DMLP) και χρησιμοποιεί μόνο τις μορφοανοσοανοσολογικές μεταβλητές. Πραγματοποιήσαμε μια αναδρομική κοόρτη 320 ασθενών που υποβλήθηκαν σε έλεγχο ODX από τρία γαλλικά νοσοκομεία. Καταγράφηκαν τα κλινικοπαθολογικά χαρακτηριστικά. Κατασκευάσαμε ένα μοντέλο ταξινόμησης με επιβλεπόμενη μηχανική μάθηση χρησιμοποιώντας το λογισμικό Matlab με 152 περιπτώσεις για την εκπαίδευση και 168 περιπτώσεις για τη δοκιμή. Χρησιμοποιήθηκαν τρεις ταξινομητές για την εκμάθηση των τριών κατηγοριών κινδύνου της ODX, δηλαδή του χαμηλού, του ενδιάμεσου και του υψηλού κινδύνου. Τα πειραματικά αποτελέσματα παρέχουν την περιοχή κάτω από την καμπύλη (AUC), αντίστοιχα, για τις τρεις κατηγορίες κινδύνου: 0,63 [95% διάστημα εμπιστοσύνης: (0,5446, 0,7154), p < 0,001], 0,59 [95% διάστημα εμπιστοσύνης: (0,5031, 0,6769), p < 0,001], 0,75 [95% διάστημα εμπιστοσύνης: (0,6184, 0,8816), p < 0,001]. Το ποσοστό συμφωνίας μεταξύ του πραγματικού RS και του προβλεπόμενου RS κυμάνθηκε από 53 έως 56% για κάθε κατηγορία μεταξύ DMLP και ODX. Το ποσοστό συμφωνίας της συνδυασμένης ομάδας χαμηλού και ενδιάμεσου κινδύνου ήταν 85%. αναπτύξαμε ένα προγνωστικό μοντέλο μηχανικής μάθησης που θα μπορούσε να βοηθήσει στον καθορισμό της RS του ασθενούς. Επιπλέον, ενσωματώσαμε τα ιστοπαθολογικά δεδομένα και τα αποτελέσματα της DMLP για την επιλογή όγκου για τη δοκιμή ODX. Έτσι, η διαδικασία αυτή επιτρέπει την πιο συναφή χρήση των ιστοπαθολογικών δεδομένων και βελτιστοποιεί και ενισχύει αυτές τις πληροφορίες.
#
# Σχετικές εργασίες και αίτηση αναφοράς:
#
# Πρόβλεψη της βαθμολογίας υποτροπής του Oncotype DX με τη χρήση βαθιών πολυεπίπεδων perceptrons σε καρκίνο του μαστού με θετικούς υποδοχείς οιστρογόνων και αρνητικό HER2
# Μάιος 2020 Καρκίνος του μαστού 27(5)
# DOI: 10.1007/s12282-020-01100-4
#
# Διάγνωση του καρκίνου του μαστού με βάση την από κοινού επιλογή μεταβλητών και το Constructive Deep Neural Network, Μάρτιος 2018, Συνέδριο: 2018 IEEE 4th Middle East Conference on Biomedical Engineering (MECBME), DOI:10.1109/MECBME.2018.8402426
#
# Constructive Deep Neural Network for Breast Cancer Diagnosis, Ιανουάριος 2018, IFAC-PapersOnLine 51(27):98-103, DOI:10.1016/j.ifacol.2018.11.660
#
# ## Target feature
#     Statur ODX
#     -   1 = low value (RS<18)
#     -   2 = mid value (RS18-30)
#     -   3 = high value (RS>30)

# %%
#Libraries
import pandas as pd

# %%
#pandas settings
pd.set_option('display.max_columns',58)
missing_values = ['NA', 'NaN', 'N/A', 'NR', ' ']

# %%
# loading the dataset
file_path = r'C:\Users\thomo\Desktop\Personal\Uni\Ptixiaki\DataSet\DataSet.xlsx'
df = pd.read_excel(file_path)
df.replace(missing_values, inplace=True)
target = 'Statut ODX'

# %%
df.head()
# Out:
#          N°Bloc  Type de prélèvement Bloc ODX  Sexe        DDN  Date diag  \
# 0  12.11.07.046                    1        E     1 1934-12-26 2012-11-16
# 1  12.12.18.104                    1      T21     1 1944-04-08 2013-01-03
# 2  13.01.08.103                    1       R1     1 1950-08-16 2013-01-17
# 3  13.01.09.009                    1       I3     1 1966-05-16 2013-01-18
# 4  13.02.05.076                    1       A5     1 1954-12-15 2013-02-14
#
#    Age au diag Ménopause  ATCD K sein  Consultation oncogénétique  Mutation   \
# 0    77.945205         1            2                         NaN        NaN
# 1    68.786301         1            0                         NaN        NaN
# 2    62.465753         1            0                         NaN        NaN
# 3    46.709589         0            0                         NaN        NaN
# 4    58.208219         0            0                         1.0        6.0
#
#    Taille tm (mm) Type de gg  Statut ganglionnaire  \
# 0              14          1                   0.0
# 1              15          1                   0.0
# 2               6          1                   1.0
# 3              80          1                   3.0
# 4              30          1                   0.0
#
#   Nombre de gg+/nb de gg prélevés Type histo Type histo associé  Grade SBR  \
# 0                             0/1          3                  1          3
# 1                             0/1          1                  5          3
# 2                             0.5          1                  1          2
# 3                             0/1          2              2 + 3          2
# 4                             0/1          1                  1          2
#
#    Grade glandes  Grade nucléaire   Grade mitoses  Emboles vasculaires  \
# 0              3                 2              3                    0
# 1              3                 3              2                    0
# 2              3                 2              1                    0
# 3              3                 2              1                    0
# 4              3                 2              1                    0
#
#    Envahissement périnerveux % Stroma  % CT  Topographie infiltrat  \
# 0                          0       20  80.0                    2.0
# 1                          0       30  70.0                    1.0
# 2                          0       70  30.0                    3.0
# 3                          0       30  70.0                    1.0
# 4                          0       20  80.0                    2.0
#
#       Stade pTNM  RE (%) RE intensité RE Allred RP (%) RP intensité RP Allred  \
# 0  T1cN0(sn)(i-)     100            3         8    100            3         8
# 1  T1cN0(sn)(i-)      90            3         8     90            3         8
# 2     T1bN1a(sn)      95            3         8     60            3         7
# 3   T3N0(sn)(i+)      90            2         7    100            3         8
# 4   T2N0(sn)(i-)     100            3         8      2            2         4
#
#   HER2 IHC HER2 SISH Ki67 % Lt stroma  % CD8 dans tumeur P53  P53 (%)  \
# 0      NaN       NaN   11           5                0.0  0*     30.0
# 1      NaN       NaN   24           5                0.0  0*     20.0
# 2      NaN       NaN   20          30                5.0  0*     10.0
# 3      NaN       NaN   11           5                1.0  0*     30.0
# 4      NaN       NaN   10           5                0.0  0*     10.0
#
#   P53 intensité  Score Oncotype Distant recurrence (%) Statut ODX RE Oncotype  \
# 0             1               2                   0.04          1        11.9
# 1             1              15                    0.1          1        11.1
# 2             1              27                   0.18          2         8.4
# 3             1              12                   0.08          1         7.8
# 4             1              16                    0.1          1        10.3
#
#   RE status O RP Oncotype RP status O HER2 Oncotype HER 2 status O  Chirurgie  \
# 0    positive         8.8    positive           7.8       négative          1
# 1    positive         9.3    positive           9.9       négative          2
# 2    positive         6.1    positive             8       négative          2
# 3    positive         8.5    positive           9.4       négative          4
# 4    positive           4    négative           9.2       négative          2
#
#   HT RT Chimithérapie                DDN.1 EDN Récidive Unnamed: 57
# 0  1  1             0  2016-06-15 00:00:00   V        0         NaN
# 1  1  1             0  2016-10-28 00:00:00   V        0         NaN
# 2  1  1             0  2015-10-16 00:00:00   V        0         NaN
# 3  1  1             0  2018-01-18 00:00:00   V        0         NaN
# 4  1  1             0  2016-10-09 00:00:00   V        0         NaN

# %%
# Iterate over each column
for column in df.columns:
    print("----", column, "----")
    
    # Calculate missing values
    missing_count = df[column].isnull().sum()
    print("Missing values:", missing_count)
    
    # Convert column to numeric if possible
    if pd.to_numeric(df[column], errors='coerce').notnull().all():
        df[column] = pd.to_numeric(df[column])
        
        # Calculate statistics
        std_deviation = df[column].std()
        print("Standard deviation:", std_deviation)
        
        mean_value = df[column].mean()
        print("Mean value:", mean_value)
        
        max_value = df[column].max()
        print("Maximum value:", max_value)
        
        min_value = df[column].min()
        print("Minimum value:", min_value)
        
    else:
        print("The feature named", column, "is not numeric")
        
    print("\n")
# Out:
# ---- N°Bloc ----
# Missing values: 0
# The feature named N°Bloc is not numeric
#
#
# ---- Type de prélèvement ----
# Missing values: 0
# Standard deviation: 0.3198398158268636
# Mean value: 0.8847352024922118
# Maximum value: 1
# Minimum value: 0
#
#
# ---- Bloc ODX ----
# Missing values: 33
# The feature named Bloc ODX is not numeric
#
#
# ---- Sexe ----
# Missing values: 0
# Standard deviation: 0.05581455721859476
# Mean value: 0.9968847352024922
# Maximum value: 1
# Minimum value: 0
#
#
# ---- DDN ----
# Missing values: 0
# Standard deviation: 3.621924357059397e+17
# Mean value: -3.579145570093458e+17
# Maximum value: 503625600000000000
# Minimum value: -1236729600000000000
#
#
# ---- Date diag ----
# Missing values: 0
# Standard deviation: 4.867620098067768e+16
# Mean value: 1.4319069308411215e+18
# Maximum value: 1547164800000000000
# Minimum value: 1345593600000000000
#
#
# ---- Age au diag ----
# Missing values: 0
# Standard deviation: 11.288386101291726
# Mean value: 56.75486706781036
# Maximum value: 83.84383561643835
# Minimum value: 30.367123287671234
#
#
# ---- Ménopause ----
# Missing values: 1
# The feature named Ménopause is not numeric
#
#
# ---- ATCD K sein ----
# Missing values: 0
# Standard deviation: 0.47238788249327457
# Mean value: 0.14330218068535824
# Maximum value: 2
# Minimum value: 0
#
#
# ---- Consultation oncogénétique ----
# Missing values: 270
# The feature named Consultation oncogénétique is not numeric
#
#
# ---- Mutation  ----
# Missing values: 271
# The feature named Mutation  is not numeric
#
#
# ---- Taille tm (mm) ----
# Missing values: 0
# Standard deviation: 11.629812171855916
# Mean value: 19.90031152647975
# Maximum value: 100
# Minimum value: 2
#
#
# ---- Type de gg ----
# Missing values: 0
# The feature named Type de gg is not numeric
#
#
# ---- Statut ganglionnaire ----
# Missing values: 9
# The feature named Statut ganglionnaire is not numeric
#
#
# ---- Nombre de gg+/nb de gg prélevés ----
# Missing values: 9
# The feature named Nombre de gg+/nb de gg prélevés is not numeric
#
#
# ---- Type histo ----
# Missing values: 0
# The feature named Type histo is not numeric
#
#
# ---- Type histo associé ----
# Missing values: 0
# The feature named Type histo associé is not numeric
#
#
# ---- Grade SBR ----
# Missing values: 0
# Standard deviation: 0.6150532484609504
# Mean value: 2.2554517133956384
# Maximum value: 3
# Minimum value: 1
#
#
# ---- Grade glandes ----
# Missing values: 0
# Standard deviation: 0.44158363411589785
# Mean value: 2.7725856697819315
# Maximum value: 3
# Minimum value: 1
#
#
# ---- Grade nucléaire  ----
# Missing values: 0
# Standard deviation: 0.5088201795112706
# Mean value: 2.311526479750779
# Maximum value: 3
# Minimum value: 1
#
#
# ---- Grade mitoses ----
# Missing values: 0
# Standard deviation: 0.7098412573187757
# Mean value: 1.8660436137071652
# Maximum value: 3
# Minimum value: 1
#
#
# ---- Emboles vasculaires ----
# Missing values: 0
# Standard deviation: 0.4001557329239459
# Mean value: 0.19937694704049844
# Maximum value: 1
# Minimum value: 0
#
#
# ---- Envahissement périnerveux ----
# Missing values: 0
# Standard deviation: 0.3160429995587522
# Mean value: 0.11214953271028037
# Maximum value: 1
# Minimum value: 0
#
#
# ---- % Stroma ----
# Missing values: 17
# The feature named % Stroma is not numeric
#
#
# ---- % CT ----
# Missing values: 25
# The feature named % CT is not numeric
#
#
# ---- Topographie infiltrat ----
# Missing values: 25
# The feature named Topographie infiltrat is not numeric
#
#
# ---- Stade pTNM ----
# Missing values: 0
# The feature named Stade pTNM is not numeric
#
#
# ---- RE (%) ----
# Missing values: 0
# Standard deviation: 10.258618441897942
# Mean value: 94.25233644859813
# Maximum value: 100
# Minimum value: 20
#
#
# ---- RE intensité ----
# Missing values: 1
# The feature named RE intensité is not numeric
#
#
# ---- RE Allred ----
# Missing values: 2
# The feature named RE Allred is not numeric
#
#
# ---- RP (%) ----
# Missing values: 0
# The feature named RP (%) is not numeric
#
#
# ---- RP intensité ----
# Missing values: 4
# The feature named RP intensité is not numeric
#
#
# ---- RP Allred ----
# Missing values: 6
# The feature named RP Allred is not numeric
#
#
# ---- HER2 IHC ----
# Missing values: 145
# The feature named HER2 IHC is not numeric
#
#
# ---- HER2 SISH ----
# Missing values: 279
# The feature named HER2 SISH is not numeric
#
#
# ---- Ki67 ----
# Missing values: 3
# The feature named Ki67 is not numeric
#
#
# ---- % Lt stroma ----
# Missing values: 19
# The feature named % Lt stroma is not numeric
#
#
# ---- % CD8 dans tumeur ----
# Missing values: 29
# The feature named % CD8 dans tumeur is not numeric
#
#
# ---- P53 ----
# Missing values: 29
# The feature named P53 is not numeric
#
#
# ---- P53 (%) ----
# Missing values: 29
# The feature named P53 (%) is not numeric
#
#
# ---- P53 intensité ----
# Missing values: 29
# The feature named P53 intensité is not numeric
#
#
# ---- Score Oncotype ----
# Missing values: 0
# Standard deviation: 9.267205308870636
# Mean value: 19.98753894080997
# Maximum value: 51
# Minimum value: 0
#
#
# ---- Distant recurrence (%) ----
# Missing values: 1
# The feature named Distant recurrence (%) is not numeric
#
#
# ---- Statut ODX ----
# Missing values: 0
# Standard deviation: 0.6797728455118864
# Mean value: 1.6168224299065421
# Maximum value: 3
# Minimum value: 1
#
#
# ---- RE Oncotype ----
# Missing values: 1
# The feature named RE Oncotype is not numeric
#
#
# ---- RE status O ----
# Missing values: 0
# The feature named RE status O is not numeric
#
#
# ---- RP Oncotype ----
# Missing values: 1
# The feature named RP Oncotype is not numeric
#
#
# ---- RP status O ----
# Missing values: 1
# The feature named RP status O is not numeric
#
#
# ---- HER2 Oncotype ----
# Missing values: 1
# The feature named HER2 Oncotype is not numeric
#
#
# ---- HER 2 status O ----
# Missing values: 1
# The feature named HER 2 status O is not numeric
#
#
# ---- Chirurgie ----
# Missing values: 0
# Standard deviation: 1.2120484835516072
# Mean value: 1.9470404984423677
# Maximum value: 4
# Minimum value: 1
#
#
# ---- HT ----
# Missing values: 0
# Standard deviation: 0.14628046717823134
# Mean value: 0.9781931464174455
# Maximum value: 1
# Minimum value: 0
#
#
# ---- RT ----
# Missing values: 0
# Standard deviation: 0.3000519165877383
# Mean value: 0.9003115264797508
# Maximum value: 1
# Minimum value: 0
#
#
# ---- Chimithérapie ----
# Missing values: 0
# Standard deviation: 1.094867308707321
# Mean value: 0.5451713395638629
# Maximum value: 6
# Minimum value: 0
#
#
# ---- DDN.1 ----
# Missing values: 17
# The feature named DDN.1 is not numeric
#
#
# ---- EDN ----
# Missing values: 17
# The feature named EDN is not numeric
#
#
# ---- Récidive ----
# Missing values: 17
# The feature named Récidive is not numeric
#
#
# ---- Unnamed: 57 ----
# Missing values: 304
# The feature named Unnamed: 57 is not numeric
